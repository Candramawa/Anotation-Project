# %%
from selenium import webdriver
import time
driver = webdriver.Chrome()
url = "https://youtu.be/EAzTfecJVPI"
driver.get(url)
print(driver.current_url)
driver.implicitly_wait(30)
# Out:
# https://www.youtube.com/watch?v=EAzTfecJVPI&feature=youtu.be

# %%
kolomK = driver.find_elements_by_xpath("//*[@id='comments']")
hasil = driver.find_elements_by_id("comment")
len(hasil)
# Out:
# 201

# %%
for comment in hasil:
    print(comment.text)
    print("====================")

# %%
judul = driver.find_element_by_xpath("//*[@id='container']/h1")
kat = driver.find_element_by_xpath("/html/body/ytd-app/div/ytd-page-manager/ytd-watch-flexy/div[4]/div[1]/div/div[9]/div[3]/ytd-video-secondary-info-renderer/div/ytd-expander/ytd-metadata-row-container-renderer/div[2]/ytd-metadata-row-renderer/div/yt-formatted-string/a")

# %%
judul.text
# Out:
# 'WARTEG FAVORIT'

# %%
kat.text
# Out:
# 'Entertainment'

# %%
tes = driver.find_elements_by_xpath("//*[@id='content-text']")

# %%
len(tes)
# Out:
# 200

# %%
for i in tes :
    print(i.text)
    print("===========================")

# %%
comment = []

# %%
j=0
for komentar in hasil:
    #isi = komentar.find_element_by_xpath("//*[@id='content-text']")
    isi = tes[j]
    c_text = komentar.text.split("\n")
    jml = komentar.find_element_by_xpath("/html/body/ytd-app/div/ytd-page-manager/ytd-watch-flexy/div[4]/div[1]/div/ytd-comments/ytd-item-section-renderer/div[3]/ytd-comment-thread-renderer[2]/ytd-comment-renderer/div[1]/div[2]/ytd-comment-action-buttons-renderer/div[1]/span[2]")
    if(len(c_text) >= 4):
        comment.append({
            'title' : judul.text,
            'category': kat.text,
            'author' : "" if len(c_text) <=3 else c_text[0],
            'comment' : isi.text,
            'like' :"" if len(c_text[-2])>4 else c_text[-2]
        })
        j=j+1

# %%
comment
# Out:
# [{'title': 'WARTEG FAVORIT',
#   'category': 'Entertainment',
#   'author': 'dana wijayanto',
#   'comment': 'Salut sama Ria yg ga pernah pilih2 makanan yg mewah2 aja dan keliatan bgt enjoy makan diwarteg dan di pinggiran jalan karena menurut aku reviewers lain kebanyakan hanya review di tempat2 yg kategori menengah keatas tapi beda dg Ria yg tetep humble walau termasuk youtuber yg sudah mumpuni, salut dah pokoknya Salam dari Malang, kapan2 main kemalang lah Ria disini buanyak makanan yg luar biasaaa',
#   'like': '1.8K'},
#  {'title': 'WARTEG FAVORIT',
#   'category': 'Entertainment',
#   'author': 'Wilhellmina Putry',
#   'comment': 'Malah fokus ke bapak2 yang jual buku pas di kedai kopi, kayaknya dia udah lelah banget jualan nya 😢',
#   'like': '795'},
#  {'title': 'WARTEG FAVORIT',
#   'category': 'Entertainment',
#   'author': 'Riski Oktavian',
#   'comment': 'Total kalori di video ini\n- Ice Cream McDonalds : 170 kcal\n- Bakso Ara : 282 kcal\n- Singkong goreng : 161 kcal',
# ...

# %%
import json
f = open('Hiburan-Warteg Favorit.json','w')
json.dump(comment, f,indent=4)
f.close()
