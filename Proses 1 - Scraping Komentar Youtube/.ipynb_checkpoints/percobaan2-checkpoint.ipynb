# %%
from selenium import webdriver
import time
driver = webdriver.Chrome()
url = "https://www.youtube.com/watch?v=kEygGb37vwM"
driver.get(url)
print(driver.current_url)
driver.implicitly_wait(30)
# Out:
# https://www.youtube.com/watch?v=kEygGb37vwM

# %%
kolomK = driver.find_elements_by_xpath("//*[@id='comments']")
hasil = driver.find_elements_by_id("comment")
len(hasil)
# Out:
# 101

# %%
for comment in hasil:
    print(comment.text)
    print("====================")

# %%
judul = driver.find_element_by_xpath("//*[@id='container']/h1")
kat = driver.find_element_by_xpath("/html/body/ytd-app/div/ytd-page-manager/ytd-watch-flexy/div[4]/div[1]/div/div[9]/div[3]/ytd-video-secondary-info-renderer/div/ytd-expander/ytd-metadata-row-container-renderer/div[2]/ytd-metadata-row-renderer/div/yt-formatted-string/a")

# %%
judul.text
# Out:
# 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang'

# %%
kat.text
# Out:
# 'Education'

# %%
tes = driver.find_elements_by_xpath("//*[@id='content-text']")

# %%
len(tes)
# Out:
# 120

# %%
for i in tes :
    print(i.text)
    print("===========================")

# %%
comment = []
# Out:
# 'Keren banget kak cania emang. Mantappu jiwa!'

# %%
j=0
for komentar in hasil:
    #isi = komentar.find_element_by_xpath("//*[@id='content-text']")
    isi = tes[j]
    like = komentar.find_element_by_xpath("/html/body/ytd-app/div/ytd-page-manager/ytd-watch-flexy/div[4]/div[1]/div/ytd-comments/ytd-item-section-renderer/div[3]/ytd-comment-thread-renderer[2]/ytd-comment-renderer/div[1]/div[2]/ytd-comment-action-buttons-renderer/div[1]/span[2]")
    c_text = komentar.text.split("\n")
    jml = komentar.find_element_by_xpath("/html/body/ytd-app/div/ytd-page-manager/ytd-watch-flexy/div[4]/div[1]/div/ytd-comments/ytd-item-section-renderer/div[3]/ytd-comment-thread-renderer[2]/ytd-comment-renderer/div[1]/div[2]/ytd-comment-action-buttons-renderer/div[1]/span[2]")
    if(len(c_text) >= 4):
        comment.append({
            'title' : judul.text,
            'category': kat.text,
            'author' : "" if len(c_text) <=3 else c_text[0],
            'comment' : isi.text,
            'like' : c_text[-2]
        })
        j=j+1

# %%
comment
# Out:
# [{'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Pinned by Geolive',
#   'comment': 'Keren banget kak cania emang. Mantappu jiwa!',
#   'like': '120'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Poer Ady',
#   'comment': 'Point di sini:\n- belajar berfikir ilmiah gak cuma di sekolah\n- connecting the dots, menghubungkan tiap informasi untuk pengambilan kesimpulan\n- kebebasan berfikir dan berpendapat',
#   'like': '426'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Yoga Rahmat',
#   'comment': 'Setuju banget dengan pernyataan Cania tentang pendidikan, dimana poin yang masih saya nilai jauh dari kata sempurna adalah kebebasan berdialektika. Masih sering saya jumpai baik di sekolah maupun kampus saya dulu, guru-guru dan dosen-dosen yang mengekang pola pikir anak didik sehingga mematikan keberanian berpendapat. Motif yang saya lihat dari tindakan tersebut adalah masih adanya rasa senioritas serta adanya sisa-sisa pola pikir dari sistem kolonialisme terdahulu yang (mungkin) membuat para guru, dosen dan tenaga pengajar merasa memiliki derajat dan martabat lebih tinggi daripada para peserta didik. Oleh karena itu, dari pengalaman saya pribadi, masih sangat sedikit tenaga pengajar di Indonesia yang mau menerima sebuah kritik, saran dan perdebatan sebagai sebuah ajang berdialektika, bukanlah sebuah ajang merendahkan martabat seseorang.',
#   'like': '230'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Clequel',
#   'comment': 'Masalahnya adalah kita tidak diajarkan secara tegas mengenai berpikir ilmiah di sekolah.. Sistem pendidikan kita masih DDCH (duduk diam catat hafal) :(',
#   'like': '227'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Gigi Kuda',
#   'comment': 'Saya bangga konten"  seperti ini viewnya sedikit.. Artinya orang" seperti kita itu langkah..',
#   'like': '79'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Mario Bimo Reksoprodjo',
#   'comment': 'Ga ada yang lebih indah daripada wanita yang berargumen. indah sekali.',
#   'like': '128'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Das Veritas',
#   'comment': 'When the majority of people are stupid, then the politician is the King of that land :)',
#   'like': '221'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'praztDR',
#   'comment': 'Hai mbaknya, saya melting dengan konten kamu.\nBtw can I req content?\nTetg berdebat, kayak pas mau pilkada kan banyak debat tuh. Gmana sih idealnya tetg berdebat dan apakah berdiskusi dengan berdebat bisa disamakan?',
#   'like': '68'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'ade akeko',
#   'comment': 'Apakah bisa berfikir ilmiah sambil emosi?\nKarena masyarakat indonesia masih banyak yg emosi duluan sebelum berfikir huhuhu',
#   'like': '145'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Erni Erni',
#   'comment': 'Kak Cania saking sayangnya sama netizen, jelasinnya sabar banget. Wkwkwk. Dikasih contoh yg paling gampang, dijelasin berkali2. Kak Cania tau kualitas pemahaman netizen. Hasilnya, yg komen positif dan nyambung. Kalau pun gak nyambung, paling cuma godain kak Cania (tapi gak direspon😂😂).\nSukses terus kak dalam mengedukasi netizen😗😗😗',
#   'like': '90'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'habek yahya',
#   'comment': 'Yg komentar berpikir ilmiah itu gapenting ada 2 org:\n1. Yg belum skripsi\n2. Yg nge-skip skripsi',
#   'like': '33'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Fariz Alhamra',
#   'comment': 'Galak nya hahaha\n"Jika nenek anda sakit Alzheimer, trs kan anda yakin dan berkesimpulan bahwa merokok dpt menyembuhkan Alzheimer. \nanda suruh lah nenek anda rokok banyak2....MODYARRRR TUH ORANG "',
#   'like': '65'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'martin viDoc',
#   'comment': 'Orientasi pendidikan kita mempersiapkan tenaga kerja unggul, bukan menyiapkan entrepreneur/profesional..\n\nDan orang2 kita (baca: ortu) masih banyak yg berorientasi "sekolah yg bener, biar dpet kerjaan enak gaji besar"',
#   'like': '23'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'c1000',
#   'comment': 'Apa cuma gue disini kalo Cania bilang "Iya kan?", terus gue jawab spontan "Yoi".',
#   'like': '60'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Astrologyna',
#   'comment': "Btw ini cowok2 straight yang komen, apalagi yg bilang suka sama cania tuh lagi nyeritain interpretasi sosok ibu di kehidupannya kayak gimana. \n\nIt's basic psychology. ",
#   'like': '54'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'dian nur cahyo',
#   'comment': 'Ini ngomongin fungsi pendidikan, kalian malah komen pertama, kedua, ketiga. Gimana sih kalian ini? Kalo gitu kan saya yang keempat.',
#   'like': '38'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'andin sefrina',
#   'comment': 'Video ini seakan jdi wake up call buat saya yg berkecimpung di dunia pendidikan tinggi, PR besar buat dosen utk membawa mhsw berpikir ilmiah dgn baik dgn reading comprehension yg baik, thanks Geolive',
#   'like': '15'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Riyan Arthur',
#   'comment': 'Sy senang dg pembahasan mbak Cania kali ini... betul pendidikan memang hrs link n match atau cari kerja atau memenuhi kebutuhan Industri... tp di sisi lain juga hrs meluluskan org2 yg menciptakan lapangan kerja (ini yg kurang terutama lulusan perguruan tinggi). Utk yg kedua di komentar lain akan coba sy argumentasikan.',
#   'like': '10'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'iqbal febri',
#   'comment': 'Ah terimakasih banyak kak , sempet kebetulan banget sebelum pop up vid kk baca status fb yang di share banyak orang yang inti dari isinya itu kalau "Di sekolah kita tidak diajarkan memanajemen uang, bernegosiasi, pokonya yang berhubungan dengan uang" .. dan munculah video kak cania yang bikin saya makin open minded banget dah, bener sekali kalo kita juga gaberfikir ilmiah dan berfikir dengan rumit pastinya orang" ga akan pernah nemu hal yang memang ga di ajarkan di sekolah',
#   'like': '46'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'faiichol',
#   'comment': 'Kenapa pola pikir orang indonesia rendah? Karena sejak dalam rahim emg keterbelakangan pendidikan alias si induk ini ga tau bagaimana cara mendidik anak dengan baik, membentuk pola pikir anak nanti, ditambah fasilitas pendidikan yg diberikan ke anak pun masih buruk. Akhirnya terus menurun pada generasi selanjutnya...',
#   'like': '19'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Alex G',
#   'comment': 'I Saw Cania, and I CLICK!\nCania sabar banget sih jelasinnya, coba aja dosenku dulu kayak kamu hehehe',
#   'like': '56'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'reffy Nanda',
#   'comment': 'Selain yang dijelaskan diatas, fungsi pendidikan adalah membentuk manusia untuk menjadi warga negara yang baik.',
#   'like': '15'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'melko maranatha',
#   'comment': 'Dialektika : Tesis, antitesis dan sintesis',
#   'like': '5'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Ryan Rizaldy',
#   'comment': 'Untuk kak Cania, saran saya belajar kedip mata ama jaja miharja coba.',
#   'like': '26'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Paristiawang nugraha',
#   'comment': '"Modar tu orang" - ka cania 2018 wkwk goks',
#   'like': '8'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Kevin Esa',
#   'comment': 'i think smart is the new "sexy" now :)',
#   'like': '52'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Anti Multazamiya',
#   'comment': 'Kak karna pendidikan di indonesia yg ga memadai. Gimana ya cara untuk meningkatkan reading comprehesion kita? Selain minta ajarin guru tentunya. Tips nya dong kak thankyou',
#   'like': '18'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Black Mamba',
#   'comment': 'Struk ditapok setan\nAids diazab\nKutil dicium setan \nAmbeien dikobel setan',
#   'like': '10'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'aryandy',
#   'comment': 'Cania, plis jangan terlalu cantik dan pintar.\nAku bisa jatuh hati❤😍',
#   'like': '4'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Patrick Star77',
#   'comment': 'Kalo semua orang indonesia punya pemikiran kaya mbak cania yg selalu "ilmiah" kaya gini, gua yakin indonesia bisa ngalahin negara2 maju. Gua selalu kagum dengan pemikiran mbak cania. Sukses terus mbak cania 🤘👍👍',
#   'like': '4'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'VJ',
#   'comment': 'terima kasih banyak mba cania pembahasan kali ini sangat bermanfaat, di sini saya menyadari bahwasanya berfikir secara ilmiah mampu membuat kita berfikir secara luas, jadi disini kita di ajarkan tidak harus mengambil keputusan, walaupun dalam keputusan tersebut dapat menguntungkan kita, namun sangat di sayangkan banyak sekali kejadian yang ada di dalam bermasyarakat dalam mengambil keputusan itu tidak harus merundingakn atau kesepakatan bersama, contohnya saja menghakimi seseorang dengan main hakim sendiri itu sering terjadi dikalangan masyarakat kita, apakah ini sudah suatu tradisinya diakalngan masyarakat kita atau memang pola pikiran kita tidak pernah berpikir logis, menurut mba cania apa yang harus di lakukan oleh kita (masyarakat) untuk mengubah pola pikir kita agar bisa berfikir secara sistematis ? terima kasih',
#   'like': '12'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'luck gun',
#   'comment': 'wah takutnya ngomong ilmiah dihadapan cewe dianggap mansplaining,kok beda-beda ya pikiran cewe',
#   'like': '5'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Rizal Khanafi',
#   'comment': '5:20 aku juga merasa jeleknya politisi yang terpilih itu salahnya rakyat juga. In a bigger picture, jelas ini efek domino.',
#   'like': '4'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Hafidh Ardianto',
#   'comment': 'Bahasan yang diangkat ringan, tp intisarinya lebih dari itu, menunggu konten2 luar biasa selanjutnya dr Geolive! :)',
#   'like': '2'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Lizam Hermansyah',
#   'comment': 'Fakta, channel seperti ini pasti sepi. Padahal channel seperti ini yang membuka wawasan cara kita berpikir.\nNetizen ternyata masih lebih tertarik sengan konten yang bahkan tidak ada Faedahnya\n😂😂😂',
#   'like': '14'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Gilang Ramadhan',
#   'comment': 'Justru gua ke yutub cari konten yg kek begini. Konten yg bisa memanusiakan manusia 👏',
#   'like': '13'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'super pell',
#   'comment': 'cantik cantik tapi pinter, bikin cwo baper sambil minder',
#   'like': '5'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Miko Saputra',
#   'comment': 'Mbak Cania, menurut saya menerapkan proses berpikir sistematis dalam menyelesaikan  setiap permasalahan kehidupan membutuhkan energi yang besar dan waktu yang lama. Sementara ada kondisi tertentu di mana kita dituntut untuk mengambil keputusan dengan cepat. Apakah dalam kondisi seperti ini kita lebih baik menggunakan insting/intuisi?',
#   'like': '24'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Esther Marcellina',
#   'comment': 'terlalu suka sama channel ini, terlalu banyak memberi informasi yang bisa menjadikan pemikiran saya terhadap suatu hal semakin baik!\nsemoga tambah banyak channel kaya gini di Indonesia.\nThanks a lot kak Cania! ❤',
#   'like': '4'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Telor Mateng',
#   'comment': 'gak cukup nonton sekali aja, setiap kata yang terucap mengandung jutaan makna yang dapat diklarifikasikan lagi menjadi sub-sub bab yang bisa dijelaskan lebih detil lagi. \n\nthank you very much for you @Cittairlanie sehat selalu cuy.',
#   'like': '4'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'gloria virginia',
#   'comment': 'Terimakasih Mba Cania. Video ini yang jelas buat saya (nitizen) mikir lagi sebelum bikin caption, nulis dan posting apapun (ngomong) untuk menanggapi segala hal. Sinau sek le..... Gak gampang le.. Salut Mba Cania!',
#   'like': '6'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Azwar Muharram',
#   'comment': 'Iya saya banyak sekali melihat komentar2 asbun dan tidak ilmiah dari masyarakat. Penyebabnya kita mudah ditipu sama berita hoax dan mitos2 akibat tidak kritis terhadap suatu informasi dan menerimanya dengan mentah2.',
#   'like': '4'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Kaka Hasan AK',
#   'comment': "Setuju banget gue dengan info yg gue dapetin disini ttg berfikir ilmiah. Apalagi di zaman skrg arus informasi yg berseliweran dmn2 dgn mudahnya kita bisa mengakses semua hal yg mau kita tau. Dan ini mnjd soal jg ketika ada orang2 yg dgn mudahnya menerima informasi hoax trs bisa di share lagi ke selainnya. Shgg ini jd info yg bisa membuat org 'terjerumus' dgn hoax tsb. Makanya butuh Banget tuh yg namanya berfikir ilmiah, misalnya dlm hal info yg kita tau. Dgn berfikir apakah bener infonya kyk gitu, terutama bagi gue pribadi pun jg gt, trs cari sumber berbagai informasi lain dan info yg didapetin harus logis dan jg dapat dipertanggungjawabkan.",
#   'like': '5'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Munzir El samuty',
#   'comment': 'sexy bgt argumentnya mbak..',
#   'like': '6'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Ang Nasution',
#   'comment': 'Channel-channel seperti yang satu ini butuh kita kembangkan untuk memberikan balance pikiran masyarakat kita yang lebih cenderung normatif.',
#   'like': '2'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Pram Pararam',
#   'comment': 'yap setuju sama cania, point² nya dapet banget— semoga banyak yg nntn sampai habis dan paham inti video nya.',
#   'like': '3'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Ron',
#   'comment': 'Hai Cania,\nSaya setuju pesan yang kamu sampaikan tentang 3 fungsi pendidikan yang seringkali samar di mata banyak orang namun kembali lagi kepada individu masing-masing.',
#   'like': '8'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Cok Dos',
#   'comment': 'Saran: put some freakin backsounds dude !! Biar gk bosenin',
#   'like': '1'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Stephen King',
#   'comment': 'Penampilannya, cara ngomongnya, suaranya, cara berpikirnya so "sexy" ❤',
#   'like': '1'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Just a Human',
#   'comment': '6:33 statement macam apa itu wkwkwk',
#   'like': '2'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Rendy Nurpratama',
#   'comment': 'Langsung naik 100 level setelah nonton video ini. :)))',
#   'like': '3'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Ikhsan Justicia',
#   'comment': 'Perempuan yang berani mengemukakan gagasannya emang terbaik sih! Semoga bisa menginsprirasi perempuan2 Indonesia lainnya ya mbak.',
#   'like': '3'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': "Haruyou's Records",
#   'comment': 'mbak cania hegelian ya?\nmakin ngefans saya kalo gini',
#   'like': '7'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'jono isme',
#   'comment': '16.07 Menit saja bersama mbak Cania merasa nyaman, tatapannya merasa ada didekatnya. Andai dia dosenku, 100 sks pun aku temui. Lufffffff!',
#   'like': '2'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'pkris',
#   'comment': 'Adem banget euy, salfok LuL ahaha',
#   'like': '3'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Irsan56',
#   'comment': 'Semoga makin banyak yg nonton video seperti ini 👍 terima kasih kak untuk penjelasan dan pencerahannya',
#   'like': '1'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Kids Jaman Now',
#   'comment': 'Langsung merasa bego sendiri ya... \n\nTerima kasih sudah mengingatkan kembali bahwa saya masih jauh dari orang yang "berpikir"',
#   'like': '2'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Ari Rizky Juliawan',
#   'comment': 'Kalo di konten ini hebat nya yang komen netizen nya cerdas semua',
#   'like': '2'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Rengga Bima',
#   'comment': '"modar tu orang" 😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂😂',
#   'like': '1'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'hasbie seiff',
#   'comment': 'Sempet pesimis di menit2 awal...\nTapi ketika tulisan problem solving muncul\nJadi melek langsung sampe akhir...\nThanks mbak citta',
#   'like': '1'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'rizky yanuar',
#   'comment': 'Sekolah,yang lebih utama perguruan tinggi adalah PENCETAK BURUH PABRIK terbesar di indonesia',
#   'like': '19'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'kevin jarwo',
#   'comment': 'Setuju banget! \nNow i have great reasons for my broke ass life and keep rolling my eyes towards rich people and their motivational speech',
#   'like': '1'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'jordan fahmi',
#   'comment': '"Yoi"',
#   'like': '"Yoi"'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Arif Saadilah',
#   'comment': 'Gue ngakak pas tiba2 mbak Cania bilang:\n"MODAR TU ORANG"\n\nNikmat banget kayaknya',
#   'like': 'Nikmat banget kayaknya'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Abdul Rahman Hakim',
#   'comment': '9:21\n\nYang pastinya itu bukan gaya nelan ludah sobat Missqueen.',
#   'like': 'Yang pastinya itu bukan gaya nelan ludah sobat Missqueen.'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Dera Apriliana',
#   'comment': 'Ka lebih sering dong upload videonya, min 1 Minggu sekali 😍',
#   'like': '1'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Mas khairil',
#   'comment': 'luar biasa cannel yang berbobo buat subcribe, jngn lupa klik lonceng juga guys.',
#   'like': '2'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Karim Salisa',
#   'comment': 'Thats great mbak can...\nTumben update cepet?',
#   'like': '3'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Kusara Channel',
#   'comment': 'Kok makin cakep Cania?',
#   'like': '4'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Adnan Karim',
#   'comment': 'Video2 seperti yang di membutuhkan share sebanyak banyaknya, Indonesia darurat perbaikan adab cuy .hehe',
#   'like': '1'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'ersinema',
#   'comment': 'ah sok ilmiah lo, ini youtube bukan sekolahan!wkwk',
#   'like': '1'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Andri Opera',
#   'comment': 'Bener banget. sekolah melatih Pola pikir sistematis.',
#   'like': '2'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Rocketjumps Clothing',
#   'comment': 'Makannya apa sih lo??!!!! Pinter banget 😊😊 jadi cinta 😘😘😘',
#   'like': '2'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Sri Agustini',
#   'comment': 'Jawaban yg aku cari dari dulu. Makasi Can ❤❤❤',
#   'like': '2'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'ROFII HAMDI',
#   'comment': '6:31  😂 😂,  thanks for made my day better',
#   'like': '6:31  😂 😂,  thanks for made my day better'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Sirait Sirait',
#   'comment': 'Benar sekali bu,  banyak belajar  otak banyak ilmu untuk membuat kesimpulan   lalu badan terutama tangan dan kaki digerak untuk melakukan.',
#   'like': '2'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Dede Elie suryadi',
#   'comment': 'Tiap nonton video dari channel ini pasti nambah pengetahuan saya, 😊',
#   'like': '3'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Nur Muhammad Iqbal',
#   'comment': "menurut saya mempunyai kemampuan berpikir kritis atau 'pintar' itu merupakan sebuah anugerah dan 'kutukan' secara bersamaan, terkadang org yg suka berpikir kritis/pintar biasanya sangat kurang dalam hal 'sosial' maka dari itu seringkali merasa selalu tidak merasa percaya dengan orang sekitar 'skeptis', kadang juga kita selalu memperhitungkan keputusan atau konsekwensi keputusan yang berlarut larut dan perfeksionis, terkadang juga di jauhi/dikucilkan oleh masyarakat yg 'ekstrovert', tapi memang diakui atau tidak, individualisme adalah produk budaya barat yang mulai di justifikasi oleh kaum 'introvert' untuk membolehkan diri untuk berbuat demikian. seharusnya orang yang dianugrahi selalu berfikir kritis membiasakan untuk mnyetting 'suspicious level/curiousity level' nya lebih rendah.",
#   'like': '23'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': "M. Iqra' R.",
#   'comment': 'In the end:\n\n"Don\'t forget to subscribe". Wink!!!!',
#   'like': '"Don\'t forget to subscribe". Wink!!!!'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Andi C. Saputra',
#   'comment': "Setuju!! Semangat kaa, I love you. You're smart!",
#   'like': "Setuju!! Semangat kaa, I love you. You're smart!"},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Pasha',
#   'comment': 'Harus diakui memang kognitif mba can lebih tinggi dr umumnya, public speaking ok, dan seperti ada tujuan jelas dr matanya kalau ingin melakukan sesuatu atas implikasi yg terjadi di kehidupan sebelumnya, semoga konten mba can bisa mencerdaskan otak dan Hati, good content',
#   'like': '2'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Fransiskus Karlos',
#   'comment': 'Mantap!!!, ni kalo bisa banyakin upload video yg kayak gini mbak dn klo bsa tiap minggu mbak',
#   'like': '1'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'afgun',
#   'comment': 'semangat kak buat konten yg seperti ini, jujur sangat membantu sekali dan bermanfaat.',
#   'like': '1'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'afin murtadho',
#   'comment': 'makin tertarik aku sama mbak Cania. :-D',
#   'like': '2'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'I am VJ',
#   'comment': 'Nice video, keep up the good work geolive!\n\nSekadar saran, kalau bisa pakai noise reduction. Soalnya pakai earphone kedengeran banget noise nya.',
#   'like': 'Read more'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'faisal mustafa',
#   'comment': 'Terimakasih mba Kania. Super cerdas!!!!',
#   'like': '2'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Aditya Purnama',
#   'comment': 'Ibarat ngasih baju yg layak ke orang yg kurang waras...ya ga bakal dipake, sama konten konten di channel ini. Semangat terus kakak❤️',
#   'like': '1'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'rauzan fikri',
#   'comment': 'undang rocky gerung dong, interview dan kritik2 :))',
#   'like': 'undang rocky gerung dong, interview dan kritik2 :))'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'ricky setiawan',
#   'comment': 'Biarkan saja kak yang nyinyir.. Makasih buat konten yang positif dan mendidik di youtube..',
#   'like': '1'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'win win 10MEI1994',
#   'comment': 'Ini youtube woy bukan sekolahan ngakak 😂😂',
#   'like': '2'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Merdeka agus saputra',
#   'comment': "I'm a big fan of you. Because of watching your videos daily I begin to love political disciplinary and read more books. Thanks for your enlightening information",
#   'like': '1'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Om Ken',
#   'comment': 'exactly!',
#   'like': '1'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Dede Gunawan',
#   'comment': 'Cantik, pintar. Subhanallah sekali',
#   'like': '2'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Muhammad Fauzan',
#   'comment': 'Worthy vlog for me, sering2lah ngebahas isu sosial politik terutama pendidikan dg se-objektif mungkin.',
#   'like': '1'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'ocow sahal',
#   'comment': 'Selalu dapet like dari saya, setiap video mis cania',
#   'like': '2'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Godhong Kemangi',
#   'comment': 'Mantappp jayaaaa... Jarang2 ada orang2 yang memiliki paradigma kalau berpikir ilmiah itu nggak cuma di sekilah atau dunia akademik saja namun untuk kehidupan sehari-hari.. sipp mbak..  walaupun gayanya agak songong.. tapi anda ilmiah, bisa dipertanggungjawabkan..',
#   'like': '2'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'iwa ikhwan',
#   'comment': 'mbak cania coba bahas dong statment para mentri, yang mengundang kontoversi di masyarakat.. (yang katanya ngawur)',
#   'like': '1'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Muhamad Arwani',
#   'comment': 'Cania lebih cantik bgni, dripada di poni rambutnya ❤❤❤❤\n\nSukses terus Caniaa ❤',
#   'like': '20'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'dipa andhika',
#   'comment': 'Anak2 FKIP wajib nonton ini...',
#   'like': '2'},
#  {'title': 'Fungsi Pendidikan Selain Supaya Bisa Nyari Uang',
#   'category': 'Education',
#   'author': 'Yourworstnightmare',
#   'comment': '4:06 best part',
#   'like': '4:06 best part'}]

# %%
import json
f = open('Education-Fungsi Pendidikan Selain Supaya Bisa Nyari Uang.json','w')
json.dump(comment, f,indent=4)
f.close()
